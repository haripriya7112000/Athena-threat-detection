# %%
import pandas as pd

# Load the dataset
file_path = "../data/CICIDS2017/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv"
df = pd.read_csv(file_path)

# Show dataset shape with returns no of rows and columns
print("Dataset shape:", df.shape) 

#all column name list
#print(df.columns.tolist())

#Clean the column names , for ex ' label' to 'label'
df.columns = df.columns.str.strip()

# Show first 5 rows if no parameter is passed
df.head(10)

# Filter and show only the rows labeled as DDoS
ddos_data = df[df['Label'] == 'DDoS']

# Display the result
#print(ddos_data)
print(ddos_data.head(10))
# Out:
# Dataset shape: (225745, 79)
#        Destination Port  Flow Duration  Total Fwd Packets  \
# 18883                80        1293792                  3
# 18884                80        4421382                  4
# 18885                80        1083538                  3
# 18886                80       80034360                  8
# 18887                80         642654                  3
# 18888                80       79731718                  8
# 18889                80         306157                  3
# 18890                80       79780371                  8
# 18891                80         682575                  3
# 18892                80       79098660                  8
#
#        Total Backward Packets  Total Length of Fwd Packets  \
# 18883                       7                           26
# 18884                       0                           24
# 18885                       6                           26
# ...
